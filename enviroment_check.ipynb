# %%
import os, sys
sys.path.append(os.path.abspath("utilities/util_functions"))
from util_helper_functions import util_find_existing_model, util_test_basemodel

# 🔹 List all models in the folder
util_find_existing_model()

# 🔹 Find a specific one
util_find_existing_model("yolo11n")

# Run a one-liner model test
util_test_basemodel()

util_test_basemodel(show=True)

util_test_basemodel(test_image_path="/home/kristoffel/utilities/util_test_images/pasta-carbonara.jpg",show=True)
# Out:
# ✅ Found model: /home/kristoffel/models/yolo11n-seg.pt
# ✅ Found model: /home/kristoffel/models/yolo11n.pt
# ✅ Found local weight: /home/kristoffel/models/yolo11n.pt
# 🖼️ Using test image: /home/kristoffel/utilities/util_test_images/Banana-Single.jpg
#
# image 1/1 /home/kristoffel/utilities/util_test_images/Banana-Single.jpg: 576x640 1 banana, 63.1ms
# Speed: 9.4ms preprocess, 63.1ms inference, 158.0ms postprocess per image at shape (1, 3, 576, 640)
# ✅ Model test successful, image identified as: banana
# ✅ Found local weight: /home/kristoffel/models/yolo11n.pt
# 🖼️ Using test image: /home/kristoffel/utilities/util_test_images/Banana-Single.jpg
#
# image 1/1 /home/kristoffel/utilities/util_test_images/Banana-Single.jpg: 576x640 1 banana, 8.1ms
# Speed: 3.4ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 576, 640)
# ✅ Model test successful, image identified as: banana
# ✅ Found local weight: /home/kristoffel/models/yolo11n.pt
# 🖼️ Using test image: /home/kristoffel/utilities/util_test_images/pasta-carbonara.jpg
#
# image 1/1 /home/kristoffel/utilities/util_test_images/pasta-carbonara.jpg: 448x640 1 cup, 1 bowl, 1 dining table, 57.9ms
# Speed: 2.0ms preprocess, 57.9ms inference, 2.5ms postprocess per image at shape (1, 3, 448, 640)
# ✅ Model test successful, image identified as: bowl, cup, dining table
# '✅ Model test successful, image identified as: bowl, cup, dining table'
