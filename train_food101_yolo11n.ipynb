# %% [markdown]
# # Food‑101 × YOLO11 — Classification Training
#
# This notebook prepares **Food‑101** (Kaggle: `dansbecker/food-101`) for YOLO‑classification and trains **YOLO11n‑cls**.
#
# **What it does:**
# 1. Reads Food‑101 `meta/train.txt` and `meta/test.txt`.
# 2. Builds `train/`, `val/`, `test/` folders with per‑class subfolders by **symlinking** from the original `images/` (falls back to copy if needed).
# 3. Trains `yolo11n-cls.pt` on the prepared splits and evaluates on both **val** and **test**.
#
# > Default validation split: **10% of the official train per class**, with a fixed random seed for reproducibility.

# %%
# --- 1) Paths & knobs ----------------------------------------------------------
import os, pathlib, random, shutil
from collections import defaultdict

DATASET_ROOT = "/home/kristoffel/datasets/dataset-02-Food-101"  # ← edit me if needed
IMAGES_DIR   = os.path.join(DATASET_ROOT, "images")
META_DIR     = os.path.join(DATASET_ROOT, "meta")

# Output splits (folders with class subfolders of symlinks/copies)
TRAIN_DIR = os.path.join(DATASET_ROOT, "train")
VAL_DIR   = os.path.join(DATASET_ROOT, "val")
TEST_DIR  = os.path.join(DATASET_ROOT, "test")

# Validation split ratio from the official train list
VAL_RATIO = 0.10  # ← edit me

# Training hyperparameters
EPOCHS = 50       # ← edit me
IMGSZ  = 224      # ← edit me (common: 224/256/320)
BATCH  = 64       # ← edit me

MODEL_DIR = "/home/kristoffel/models"
RUN_NAME  = "food101_yolo11n_cls"

# Reproducibility
SEED = 42
random.seed(SEED)

# Sanity checks
for p in (IMAGES_DIR, META_DIR):
    assert os.path.isdir(p), f"Missing: {p} — run the download notebook first."
os.makedirs(MODEL_DIR, exist_ok=True)
print("Paths OK.")
# Out:
# Paths OK.

# %%
# --- 2) Read meta files: classes, train/test lists ----------------------------
from pathlib import Path

classes_txt = Path(META_DIR) / "classes.txt"
train_txt   = Path(META_DIR) / "train.txt"
test_txt    = Path(META_DIR) / "test.txt"

classes = [ln.strip() for ln in classes_txt.read_text().splitlines() if ln.strip()]
print(f"Found {len(classes)} classes.")
assert len(classes) == 101, f"Expected 101 classes, got {len(classes)}"

def read_list(p: Path):
    # Lines like: class_name/image_stem  (no .jpg extension)
    out = defaultdict(list)
    for ln in p.read_text().splitlines():
        ln = ln.strip()
        if not ln: 
            continue
        cls, stem = ln.split("/")
        out[cls].append(stem + ".jpg")
    return out

train_list = read_list(train_txt)
test_list  = read_list(test_txt)

# Basic cardinality checks (Food-101 official split: 750 train, 250 test per class)
n_train = sum(len(v) for v in train_list.values())
n_test  = sum(len(v) for v in test_list.values())
print(f"Train images listed: {n_train}; Test images listed: {n_test}")
# Out:
# Found 101 classes.
# Train images listed: 75750; Test images listed: 25250

# %%
# --- 3) Build train/val/test folders using symlinks from images/ --------------
import os, errno

# Clean old splits
for d in (TRAIN_DIR, VAL_DIR, TEST_DIR):
    if os.path.isdir(d):
        shutil.rmtree(d)
    os.makedirs(d, exist_ok=True)

def safe_link(src, dst):
    try:
        os.symlink(src, dst)
    except (OSError, NotImplementedError) as e:
        # Fallback to copying if symlinks are not permitted
        shutil.copy2(src, dst)

# Create per-class dirs
for cls in classes:
    os.makedirs(os.path.join(TRAIN_DIR, cls), exist_ok=True)
    os.makedirs(os.path.join(VAL_DIR, cls),   exist_ok=True)
    os.makedirs(os.path.join(TEST_DIR, cls),  exist_ok=True)

# Allocate val from train per class deterministically
for cls in classes:
    pool = list(train_list[cls])
    random.shuffle(pool)
    k_val = max(1, int(len(pool) * VAL_RATIO))
    val_subset = set(pool[:k_val])
    train_subset = pool[k_val:]

    # Link training subset
    for fname in train_subset:
        src = os.path.join(IMAGES_DIR, cls, fname)
        dst = os.path.join(TRAIN_DIR,  cls, fname)
        if not os.path.isfile(src):
            raise FileNotFoundError(f"Missing image: {src}")
        safe_link(src, dst)

    # Link validation subset
    for fname in val_subset:
        src = os.path.join(IMAGES_DIR, cls, fname)
        dst = os.path.join(VAL_DIR,    cls, fname)
        if not os.path.isfile(src):
            raise FileNotFoundError(f"Missing image: {src}")
        safe_link(src, dst)

# Link official test set
for cls in classes:
    for fname in test_list[cls]:
        src = os.path.join(IMAGES_DIR, cls, fname)
        dst = os.path.join(TEST_DIR,   cls, fname)
        if not os.path.isfile(src):
            raise FileNotFoundError(f"Missing image: {src}")
        safe_link(src, dst)

print("Splits built:")
print(" train ->", TRAIN_DIR)
print(" val   ->", VAL_DIR)
print(" test  ->", TEST_DIR)

# Remove any stale Ultralytics caches if present
for split in ("train","val","test"):
    cache = Path(DATASET_ROOT) / f"{split}.cache"
    if cache.exists():
        cache.unlink()
        print("removed cache:", cache)
# Out:
# Splits built:
#  train -> /home/kristoffel/datasets/dataset-02-Food-101/train
#  val   -> /home/kristoffel/datasets/dataset-02-Food-101/val
#  test  -> /home/kristoffel/datasets/dataset-02-Food-101/test

# %%
# --- 4) Quick counts and verification -----------------------------------------
import os
def count_imgs(root):
    tot = 0
    for cls in classes:
        cdir = os.path.join(root, cls)
        n = sum(1 for _r, _d, fs in os.walk(cdir) for _f in fs if _f.lower().endswith(('.jpg','.jpeg','.png','.webp','.bmp','.tif','.tiff')))
        tot += n
    return tot

print("train images:", count_imgs(TRAIN_DIR))
print("val images  :", count_imgs(VAL_DIR))
print("test images :", count_imgs(TEST_DIR))

# Ensure class sets match across splits
def list_class_dirs(root):
    return sorted([d for d in os.listdir(root) if os.path.isdir(os.path.join(root,d))])
assert list_class_dirs(TRAIN_DIR) == list_class_dirs(VAL_DIR) == list_class_dirs(TEST_DIR) == sorted(classes), "Class folder mismatch across splits"
print("✅ Class folders align across all splits.")
# Out:
# train images: 68175
# val images  : 7575
# test images : 25250
# ✅ Class folders align across all splits.

# %%
# --- 5) Train YOLO11n-cls -----------------------------------------------------
# Make sure ultralytics is installed (uncomment pip if needed)
# !pip install -U ultralytics

import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

from ultralytics import YOLO
import ultralytics, torch

print("Ultralytics:", ultralytics.__version__)
print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device:", torch.cuda.get_device_name(0))

model = YOLO("yolo11n-cls.pt")  # classification weights
results = model.train(
    data=DATASET_ROOT,       # directory with train/val/test
    epochs=EPOCHS,
    imgsz=IMGSZ,
    batch=BATCH,
    lr0=1e-3,
    patience=10,
    project=MODEL_DIR,
    name=RUN_NAME,
    plots=True,
    device=0 if torch.cuda.is_available() else "cpu",
)
print("Training run saved to:", results.save_dir)
# Out:
# Ultralytics: 8.3.203
# PyTorch: 2.2.0a0+81ea7a4
# CUDA available: True
# Device: Tesla V100-SXM3-32GB
# New https://pypi.org/project/ultralytics/8.3.223 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.203 🚀 Python-3.10.12 torch-2.2.0a0+81ea7a4 CUDA:0 (Tesla V100-SXM3-32GB, 32494MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/kristoffel/datasets/dataset-02-Food-101, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=food101_yolo11n_cls, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/home/kristoffel/models, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/kristoffel/models/food101_yolo11n_cls, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /home/kristoffel/datasets/dataset-02-Food-101/train... found 68175 images in 101 classes ✅
# val: /home/kristoffel/datasets/dataset-02-Food-101/val... found 7575 images in 101 classes ✅
# test: /home/kristoffel/datasets/dataset-02-Food-101/test... found 25250 images in 101 classes ✅
# Overriding model.yaml nc=80 with nc=101
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    459621  ultralytics.nn.modules.head.Classify         [256, 101]
# YOLO11n-cls summary: 86 layers, 1,660,485 parameters, 1,660,485 gradients, 3.4 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1270.2±343.8 MB/s, size: 48.3 KB)
# train: Scanning /home/kristoffel/datasets/dataset-02-Food-101/train... 31244 images, 0 corrupt: 46% ━━━━━─────── 31244/68175 3.8Kit/s 8.5s<9.8ss
# /usr/local/lib/python3.10/dist-packages/PIL/TiffImagePlugin.py:870: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# train: Scanning /home/kristoffel/datasets/dataset-02-Food-101/train... 68175 images, 0 corrupt: 100% ━━━━━━━━━━━━ 68175/68175 3.6Kit/s 18.8s<0.1s
# train: New cache created: /home/kristoffel/datasets/dataset-02-Food-101/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1197.6±532.3 MB/s, size: 58.6 KB)
# val: Scanning /home/kristoffel/datasets/dataset-02-Food-101/val... 7575 images, 0 corrupt: 100% ━━━━━━━━━━━━ 7575/7575 2.9Kit/s 2.6s0.1s
# val: New cache created: /home/kristoffel/datasets/dataset-02-Food-101/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to /home/kristoffel/models/food101_yolo11n_cls
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50     0.869G      3.336         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.1it/s 58.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.3it/s 3.0s0.1s
#                    all      0.546      0.797
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50     0.941G      1.814         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.4it/s 54.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.1it/s 3.0s0.1s
#                    all      0.589       0.83
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50     0.941G      1.834         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.3it/s 55.3s<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 21.1it/s 2.8s0.2s
#                    all       0.52      0.795
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50     0.943G       1.85         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.5it/s 54.6s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 19.0it/s 3.2s0.2s
#                    all      0.593      0.836
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/50     0.943G      1.668         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.4it/s 54.9s<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.7it/s 2.9s0.1s
#                    all      0.638      0.865
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/50     0.943G      1.576         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.4it/s 54.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 19.3it/s 3.1s0.1s
#                    all      0.675      0.886
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/50     0.943G      1.498         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.5it/s 54.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.3it/s 2.9s0.2s
#                    all        0.7      0.892
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/50     0.943G      1.452         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.4it/s 54.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.5it/s 2.9s0.1s
#                    all       0.72      0.905
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/50     0.943G      1.405         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.1it/s 55.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 22.8it/s 2.6s0.2s
#                    all      0.732      0.916
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/50     0.943G      1.367         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.3it/s 55.2s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 22.2it/s 2.7s0.2s
#                    all      0.737      0.919
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/50     0.943G      1.337         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.5it/s 54.7s<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 18.8it/s 3.2s0.2s
#                    all      0.743      0.921
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/50     0.943G      1.306         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.5it/s 54.7s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 19.7it/s 3.0s0.2s
#                    all      0.749      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/50     0.943G      1.276         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.0it/s 56.0s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 21.7it/s 2.8s0.1s
#                    all      0.756      0.927
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/50     0.943G      1.256         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.5it/s 54.6s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 19.4it/s 3.1s0.1s
#                    all      0.759      0.928
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/50     0.943G      1.237         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.0it/s 56.0s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 22.3it/s 2.7s0.2s
#                    all       0.76       0.93
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/50     0.943G      1.207         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.4it/s 55.1s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.3it/s 3.0s0.1s
#                    all      0.762      0.928
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/50     0.943G      1.186         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.5it/s 54.8s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 19.4it/s 3.1s0.1s
#                    all      0.764       0.93
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/50     0.943G       1.16         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.6it/s 54.5s<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 19.8it/s 3.0s0.2s
#                    all      0.763       0.93
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/50     0.943G      1.141         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.9it/s 56.5s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 22.9it/s 2.6s0.2s
#                    all      0.765       0.93
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/50     0.943G       1.12         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.5it/s 57.7s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 22.0it/s 2.7s0.2s
#                    all      0.768      0.931
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/50     0.943G      1.102         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.2it/s 58.6s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 23.0it/s 2.6s0.1s
#                    all      0.769       0.93
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/50     0.943G      1.079         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.4it/s 57.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 21.3it/s 2.8s0.1s
#                    all       0.77      0.931
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/50     0.943G       1.06         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.8it/s 56.7s<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 22.3it/s 2.7s0.2s
#                    all      0.772      0.931
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/50     0.943G      1.039         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.9it/s 56.5s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 21.7it/s 2.8s0.1s
#                    all      0.773      0.931
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/50     0.943G      1.008         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.9it/s 56.4s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 23.3it/s 2.6s0.2s
#                    all      0.775      0.932
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/50     0.943G      0.999         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.3it/s 55.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 21.0it/s 2.9s0.1s
#                    all      0.776      0.931
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/50     0.943G     0.9732         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.8it/s 56.8s<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 22.7it/s 2.6s0.2s
#                    all      0.776      0.932
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/50     0.943G     0.9549         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.2it/s 58.6s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 22.1it/s 2.7s0.1s
#                    all      0.778      0.931
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/50     0.943G     0.9344         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.4it/s 54.9s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.4it/s 2.9s0.2s
#                    all      0.777      0.933
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/50     0.943G     0.9164         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.5it/s 54.6s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 19.0it/s 3.2s0.1s
#                    all      0.778      0.933
#
#       Epoch    GPU_mem       loss  Instances       Size
#       31/50     0.943G     0.8884         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.5it/s 54.6s<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 19.1it/s 3.1s0.1s
#                    all      0.779      0.934
#
#       Epoch    GPU_mem       loss  Instances       Size
#       32/50     0.943G     0.8636         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.5it/s 54.7s<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.1it/s 3.0s0.2s
#                    all      0.779      0.934
#
#       Epoch    GPU_mem       loss  Instances       Size
#       33/50     0.943G     0.8331         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.7it/s 56.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 22.3it/s 2.7s0.2s
#                    all      0.781      0.934
#
#       Epoch    GPU_mem       loss  Instances       Size
#       34/50     0.943G     0.8114         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.1it/s 55.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.7it/s 2.9s0.1s
#                    all      0.781      0.934
#
#       Epoch    GPU_mem       loss  Instances       Size
#       35/50     0.943G     0.7879         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.6it/s 57.2s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 23.1it/s 2.6s0.2s
#                    all      0.782      0.933
#
#       Epoch    GPU_mem       loss  Instances       Size
#       36/50     0.943G       0.76         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.7it/s 57.1s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 22.1it/s 2.7s0.2s
#                    all      0.782      0.935
#
#       Epoch    GPU_mem       loss  Instances       Size
#       37/50     0.943G     0.7238         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.4it/s 57.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 22.5it/s 2.7s0.1s
#                    all      0.782      0.935
#
#       Epoch    GPU_mem       loss  Instances       Size
#       38/50     0.943G     0.6964         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.5it/s 54.7s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 18.5it/s 3.2s0.1s
#                    all      0.783      0.935
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/50     0.943G     0.6741         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.5it/s 54.7s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.6it/s 2.9s0.2s
#                    all      0.784      0.935
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/50     0.943G     0.6401         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.4it/s 55.1s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.9it/s 2.9s0.2s
#                    all      0.785      0.935
#
#       Epoch    GPU_mem       loss  Instances       Size
#       41/50     0.943G     0.6179         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.4it/s 57.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.5it/s 2.9s0.2s
#                    all      0.785      0.935
#
#       Epoch    GPU_mem       loss  Instances       Size
#       42/50     0.943G     0.5846         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.1it/s 55.9s<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.4it/s 2.9s0.2s
#                    all      0.785      0.935
#
#       Epoch    GPU_mem       loss  Instances       Size
#       43/50     0.943G     0.5495         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.8it/s 56.6s<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 21.4it/s 2.8s0.1s
#                    all      0.786      0.935
#
#       Epoch    GPU_mem       loss  Instances       Size
#       44/50     0.943G       0.52         15        224: 100% ━━━━━━━━━━━━ 1066/1066 18.6it/s 57.2s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.8it/s 2.9s0.1s
#                    all      0.786      0.936
#
#       Epoch    GPU_mem       loss  Instances       Size
#       45/50     0.943G     0.4944         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.0it/s 56.0s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.3it/s 3.0s0.1s
#                    all      0.786      0.937
#
#       Epoch    GPU_mem       loss  Instances       Size
#       46/50     0.943G     0.4673         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.0it/s 56.1s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.5it/s 2.9s0.2s
#                    all      0.785      0.937
#
#       Epoch    GPU_mem       loss  Instances       Size
#       47/50     0.943G     0.4333         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.2it/s 55.6s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.0it/s 3.0s0.2s
#                    all      0.785      0.937
#
#       Epoch    GPU_mem       loss  Instances       Size
#       48/50     0.943G     0.4131         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.2it/s 55.4s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 20.4it/s 2.9s0.2s
#                    all      0.786      0.937
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/50     0.943G     0.3874         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.3it/s 55.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 19.2it/s 3.1s0.2s
#                    all      0.785      0.937
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/50     0.943G     0.3635         15        224: 100% ━━━━━━━━━━━━ 1066/1066 19.3it/s 55.2s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 19.6it/s 3.1s0.1s
#                    all      0.788      0.937
#
# 50 epochs completed in 0.818 hours.
# Optimizer stripped from /home/kristoffel/models/food101_yolo11n_cls/weights/last.pt, 3.4MB
# Optimizer stripped from /home/kristoffel/models/food101_yolo11n_cls/weights/best.pt, 3.4MB
#
# Validating /home/kristoffel/models/food101_yolo11n_cls/weights/best.pt...
# Ultralytics 8.3.203 🚀 Python-3.10.12 torch-2.2.0a0+81ea7a4 CUDA:0 (Tesla V100-SXM3-32GB, 32494MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,655,405 parameters, 0 gradients, 3.3 GFLOPs
# train: /home/kristoffel/datasets/dataset-02-Food-101/train... found 68175 images in 101 classes ✅
# val: /home/kristoffel/datasets/dataset-02-Food-101/val... found 7575 images in 101 classes ✅
# test: /home/kristoffel/datasets/dataset-02-Food-101/test... found 25250 images in 101 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 60/60 22.6it/s 2.7s0.2s
#                    all      0.788      0.936
# Speed: 0.1ms preprocess, 0.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /home/kristoffel/models/food101_yolo11n_cls
# Training run saved to: /home/kristoffel/models/food101_yolo11n_cls

# %%
# --- 6) Evaluate on val and test ----------------------------------------------
from ultralytics import YOLO
import glob, os, torch

RUN_PREFIX = RUN_NAME
cands = glob.glob(os.path.join(MODEL_DIR, RUN_PREFIX + "*", "weights", "best.pt"))
assert cands, f"No best.pt found under {MODEL_DIR}/{RUN_PREFIX}*/weights/"
best_path = max(cands, key=os.path.getmtime)
print("Using best:", best_path)

IMGSZ = IMGSZ  # keep consistent

model = YOLO(best_path)

metrics_val = model.val(
    data=DATASET_ROOT,
    split="val",
    imgsz=IMGSZ,
    project=MODEL_DIR,
    name=RUN_PREFIX + "_val",
    device=0 if torch.cuda.is_available() else "cpu",
)

metrics_test = model.val(
    data=DATASET_ROOT,
    split="test",
    imgsz=IMGSZ,
    project=MODEL_DIR,
    name=RUN_PREFIX + "_test",
    device=0 if torch.cuda.is_available() else "cpu",
)
print("Done. Check metrics and plots under:", MODEL_DIR)
# Out:
# Using best: /home/kristoffel/models/food101_yolo11n_cls/weights/best.pt
# Ultralytics 8.3.203 🚀 Python-3.10.12 torch-2.2.0a0+81ea7a4 CUDA:0 (Tesla V100-SXM3-32GB, 32494MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,655,405 parameters, 0 gradients, 3.3 GFLOPs
# train: /home/kristoffel/datasets/dataset-02-Food-101/train... found 68175 images in 101 classes ✅
# val: /home/kristoffel/datasets/dataset-02-Food-101/val... found 7575 images in 101 classes ✅
# test: /home/kristoffel/datasets/dataset-02-Food-101/test... found 25250 images in 101 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1279.2±262.2 MB/s, size: 58.6 KB)
# val: Scanning /home/kristoffel/datasets/dataset-02-Food-101/val... 7575 images, 0 corrupt: 100% ━━━━━━━━━━━━ 7575/7575 12.7Mit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 474/474 96.0it/s 4.9s<0.1s
#                    all      0.787      0.937
# Speed: 0.1ms preprocess, 0.3ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /home/kristoffel/models/food101_yolo11n_cls_val
# Ultralytics 8.3.203 🚀 Python-3.10.12 torch-2.2.0a0+81ea7a4 CUDA:0 (Tesla V100-SXM3-32GB, 32494MiB)
# train: /home/kristoffel/datasets/dataset-02-Food-101/train... found 68175 images in 101 classes ✅
# val: /home/kristoffel/datasets/dataset-02-Food-101/val... found 7575 images in 101 classes ✅
# test: /home/kristoffel/datasets/dataset-02-Food-101/test... found 25250 images in 101 classes ✅
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 745.8±228.2 MB/s, size: 37.4 KB)
# test: Scanning /home/kristoffel/datasets/dataset-02-Food-101/test... 704 images, 0 corrupt: 3% ──────────── 704/25250 1.8Kit/s 0.2s<13.6s
# /usr/local/lib/python3.10/dist-packages/PIL/TiffImagePlugin.py:870: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# test: Scanning /home/kristoffel/datasets/dataset-02-Food-101/test... 25250 images, 0 corrupt: 100% ━━━━━━━━━━━━ 25250/25250 3.6Kit/s 7.0s0.1s
# test: New cache created: /home/kristoffel/datasets/dataset-02-Food-101/test.cache
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 1579/1579 100.9it/s 15.6s<0.0s
#                    all      0.838      0.963
# Speed: 0.1ms preprocess, 0.3ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /home/kristoffel/models/food101_yolo11n_cls_test
# Done. Check metrics and plots under: /home/kristoffel/models

# %%
# --- 7) Quick prediction preview ----------------------------------------------
from ultralytics import YOLO
import random, glob, os

best_weights = best_path  # from previous cell
model = YOLO(best_weights)

# Sample up to 16 test images
cand = []
for cls in classes:
    cand += glob.glob(os.path.join(TEST_DIR, cls, "*.jpg"))
sample = random.sample(cand, k=min(16, len(cand))) if cand else []

out_name = RUN_NAME + "_preds"
if sample:
    _ = model.predict(
        source=sample,
        save=True,
        project=MODEL_DIR,
        name=out_name
    )
    print("Saved prediction previews to:", os.path.join(MODEL_DIR, out_name))
else:
    print("No test images found to preview.")
# Out:
# 0: 224x224 lobster_roll_sandwich 1.00, club_sandwich 0.00, pulled_pork_sandwich 0.00, bruschetta 0.00, eggs_benedict 0.00, 0.3ms
# 1: 224x224 panna_cotta 0.97, chocolate_mousse 0.01, chocolate_cake 0.00, cheesecake 0.00, foie_gras 0.00, 0.3ms
# 2: 224x224 caprese_salad 0.59, bruschetta 0.39, beet_salad 0.01, beef_carpaccio 0.00, tuna_tartare 0.00, 0.3ms
# 3: 224x224 garlic_bread 0.98, apple_pie 0.01, bruschetta 0.00, pizza 0.00, french_toast 0.00, 0.3ms
# 4: 224x224 huevos_rancheros 1.00, breakfast_burrito 0.00, tacos 0.00, nachos 0.00, omelette 0.00, 0.3ms
# 5: 224x224 french_onion_soup 0.49, macaroni_and_cheese 0.20, clam_chowder 0.11, lasagna 0.07, gnocchi 0.03, 0.3ms
# 6: 224x224 pulled_pork_sandwich 1.00, prime_rib 0.00, hot_dog 0.00, grilled_cheese_sandwich 0.00, hamburger 0.00, 0.3ms
# 7: 224x224 red_velvet_cake 1.00, carrot_cake 0.00, chocolate_cake 0.00, churros 0.00, tiramisu 0.00, 0.3ms
# 8: 224x224 crab_cakes 0.49, gnocchi 0.13, grilled_salmon 0.05, macaroni_and_cheese 0.05, shrimp_and_grits 0.05, 0.3ms
# 9: 224x224 pancakes 1.00, apple_pie 0.00, french_toast 0.00, tiramisu 0.00, cheesecake 0.00, 0.3ms
# 10: 224x224 macaroni_and_cheese 1.00, gnocchi 0.00, scallops 0.00, dumplings 0.00, ravioli 0.00, 0.3ms
# 11: 224x224 panna_cotta 0.99, cheesecake 0.01, pancakes 0.00, escargots 0.00, tiramisu 0.00, 0.3ms
# 12: 224x224 onion_rings 1.00, strawberry_shortcake 0.00, deviled_eggs 0.00, macarons 0.00, fish_and_chips 0.00, 0.3ms
# 13: 224x224 eggs_benedict 1.00, croque_madame 0.00, hamburger 0.00, omelette 0.00, pulled_pork_sandwich 0.00, 0.3ms
# 14: 224x224 bread_pudding 1.00, apple_pie 0.00, tiramisu 0.00, baklava 0.00, creme_brulee 0.00, 0.3ms
# 15: 224x224 paella 0.41, poutine 0.15, fried_calamari 0.10, ceviche 0.03, nachos 0.03, 0.3ms
# Speed: 3.1ms preprocess, 0.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /home/kristoffel/models/food101_yolo11n_cls_preds
# Saved prediction previews to: /home/kristoffel/models/food101_yolo11n_cls_preds
