# %%
# !pip install kagglehub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip

# %%
# !python download_food11.py --out /home/kristoffel/datasets/dataset-03-Food-11 --force
# Out:
# [1/3] Downloading via kagglehub: trolukovich/food11-image-dataset
# [2/3] KaggleHub cache at: /home/kristoffel/.cache/kagglehub/datasets/trolukovich/food11-image-dataset/versions/1
# [force] Removing existing folder: /home/kristoffel/datasets/dataset-03-Food-11
# [3/3] Copying to: /home/kristoffel/datasets/dataset-03-Food-11
# ✅ Done.
# Path to dataset files: /home/kristoffel/datasets/dataset-03-Food-11
