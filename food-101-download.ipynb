# %% [markdown]
# # Food‑101 — Download notebook
#
# This notebook downloads the **Food‑101** dataset from Kaggle via `kagglehub`
#
# **Output path:**
# ```
# /home/kristoffel/datasets/dataset-02-Food-101
# ```

# %%
# Install kagglehub if not already installed
# If you hit auth issues, see https://github.com/Kaggle/kagglehub
# !pip install -U kagglehub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip

# %%
# Download and copy to the desired location
# !python download_food101.py --out /home/kristoffel/datasets/dataset-02-Food-101 --force
# Out:
# [1/6] Downloading via kagglehub: dansbecker/food-101
# [2/6] KaggleHub cache at: /home/kristoffel/.cache/kagglehub/datasets/dansbecker/food-101/versions/1
# [force] Removing existing folder: /home/kristoffel/datasets/dataset-02-Food-101
# [3/6] Found images/meta under: /home/kristoffel/.cache/kagglehub/datasets/dansbecker/food-101/versions/1/food-101/food-101
# [4/6] Copying images -> /home/kristoffel/datasets/dataset-02-Food-101/images
# [5/6] Copying meta -> /home/kristoffel/datasets/dataset-02-Food-101/meta
# [6/6] Verify:
#   images: /home/kristoffel/datasets/dataset-02-Food-101/images (101 class folders)
#   meta  : /home/kristoffel/datasets/dataset-02-Food-101/meta
# ✅ Done.
# Path to dataset files: /home/kristoffel/datasets/dataset-02-Food-101
