# %% [markdown]
# # Nutrition5k — Download notebook
#
# This notebook downloads **Nutrition5k** via `kagglehub` and places it at:
# ```
# /home/kristoffel/datasets/dataset-01-Nutrition5k
# ```
#
# Default Kaggle ref: `siddhantrout/nutrition5k-dataset`

# %%
# Install kagglehub if not already installed
# !pip install -U kagglehub

# %%
# Download and copy to the desired location
# !python download_nutrition5k.py --out /home/kristoffel/datasets/dataset-01-Nutrition5k --force
# Out:
# [1/3] Downloading via kagglehub: siddhantrout/nutrition5k-dataset
# ...
# 100%|██████████████████████████████████████| 2.29G/2.29G [01:15<00:00, 32.5MB/s]
# Extracting files...
# [2/3] KaggleHub cache at: /home/kristoffel/.cache/kagglehub/datasets/siddhantrout/nutrition5k-dataset/versions/1
# [3/3] Copying to: /home/kristoffel/datasets/dataset-01-Nutrition5k
# ✅ Done.
# Path to dataset files: /home/kristoffel/datasets/dataset-01-Nutrition5k
# Note: If this ref stores images as bytes inside tables, use the training notebook to materialize JPEGs.
